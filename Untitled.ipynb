# %%
# %load_ext ml_optic
# Out:
# marklogic optic magic loaded.

# %%
# %%ml_optic?

# %%
# %%ml_optic xquery://admin:admin@localhost:8059
# xquery version "1.0-ml";
#
# import module namespace op="http://marklogic.com/optic"
#      at "/MarkLogic/optic.xqy";
#
# op:from-view("zomato", "reviews")
#    => op:select(("Id", "Name", "Locality"))
#    => op:order-by("Id")
#    => op:limit(19)
#    => op:result()
# Out:
# Returned 1 results
# DataFrame returned in ml_optic

# %%
ml_optic
# Out:
#                                                     0  \
# 0   {'name': 'zomato.reviews.Id', 'type': 'xs:stri...
# 1                                              100305
# 2                                              100306
# 3                                              101212
# 4                                              101259
# 5                                              101311
# 6                                                1018
# 7                                              101834
# 8                                              101884
# 9                                                1019
# 10                                               1021
# 11                                             102215
# 12                                             102216
# 13                                               1023
# 14                                             102504
# 15                                             102531
# ...
